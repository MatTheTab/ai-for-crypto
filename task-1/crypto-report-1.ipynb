# %% [markdown]
# # ML for Crypto - Task 1

# %% [markdown]
# ## Imports

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from utils.crypto_ml_utils import compressed_or_binary_classification_pipeline, complete_classification_pipeline

# %% [markdown]
# ## Experiments - Un-Encrypted vs Random (Encrypted)

# %%
models = [
    ("Logistic Regression", LogisticRegression(max_iter=500)),
    ("Random Forest", RandomForestClassifier(n_estimators=100))
]

compressed_or_binary_classification_pipeline(
    models,
    n_bins=20)
# Out:
# =========Stats==========
#
# *********Raw Data*********
# Stats Mean:
# Mean Entropy Bits: 0.961583
# Mean Entropy Bits (Ideal): 1.000000
# Mean Entropy Bytes: 4.448631
# Mean Entropy Bytes (Ideal): 8.000000
# Mean Chi-Squared P-val: 0.000000
# Mean Compressibility: 0.172169
# Mean Serial Correlation: 0.628367
# Mean FFT: 0.305746
# Mean ECB Indicator: 0.182457
#
# Stats, Complete Dataset
# Entropy Bits: 0.963132
# Entropy Bits (Ideal): 1.000000
# Entropy Bytes: 4.635049
# Entropy Bytes (Ideal): 8.000000
# Chi-Squared P-val: 0.000000
# Compressibility: 0.153327
# Serial Correlation: 0.636812
# FFT: 0.313500
# ECB Indicator: 0.400131
#
# *********AES ECB*********
# Stats Mean:
# Mean Entropy Bits: 0.999972
# Mean Entropy Bits (Ideal): 1.000000
# Mean Entropy Bytes: 7.983047
# Mean Entropy Bytes (Ideal): 8.000000
# Mean Chi-Squared P-val: 0.007742
# Mean Compressibility: 0.842362
# Mean Serial Correlation: -0.003349
# Mean FFT: 0.559780
# Mean ECB Indicator: 0.182457
#
# ...

# %% [markdown]
# ## Experiments - All Dataset Pairs

# %%
models = [
    ("Logistic Regression", LogisticRegression(max_iter=500))
]

complete_classification_pipeline(models, owner="pytorch", repo="pytorch", branch="main", num_files=20)
