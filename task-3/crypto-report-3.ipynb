# %% [markdown]
# # S-Box Experiments

# %% [markdown]
# ## Imports

# %%
from utils.metrics.NonLinearity import NonLinearity
from utils.metrics.DifferentialUniformity import DifferentialUniformity
from utils.metrics.StrictAvalancheCriterion import StrictAvalancheCriterion
from utils.metrics.BitIndependeceCriterion import BitIndependeceCriterion
from utils.metrics.FixedOppositePoints import FixedOppositePoints
from utils.metrics.AlgebraicDegree import AlgebraicDegree
from utils.parsing import parse_all_files
from utils.plotting.results import plot_histories, plot_times, plot_metrics_scatter
from utils.metrics.summarize import calculate_results_statistics

# %% [markdown]
# ## Results Analysis

# %%
nonlinearity = NonLinearity()
du = DifferentialUniformity()
sac = StrictAvalancheCriterion()
bic = BitIndependeceCriterion()
fop = FixedOppositePoints()
ad = AlgebraicDegree()

metric_functions={
    "Non-Linearity": nonlinearity,
    "Differential Uniformity": du,
    "Strict Avalanche Criterion": sac,
    "Bit Independece Criterion": bic,
    "Fixed points and opposite fixed points": fop,
    "Algebraic Degree": ad,
}

results_dir = "./results"
all_metrics, all_times, all_histories = parse_all_files(results_dir, metric_functions)

# %%
plot_histories(all_histories, save_dir="./plots/results")

plot_times(all_times, save_dir="./plots/results")

plot_metrics_scatter(all_metrics, ["Non-Linearity", "Differential Uniformity"], save_dir="./plots/results")

plot_metrics_scatter(
     all_metrics, 
     ["Non-Linearity", "Differential Uniformity", "Strict Avalanche Criterion"], 
     save_dir="./plots/results"
)
# Out:
# Saved histories plot to ./plots/results/histories_nonlinearities.png
# /home/matthetab/codebase/ai-for-crypto/task-3/utils/plotting/results.py:62: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# Saved times plot to ./plots/results/execution_times_violin.png
# Saved 2D scatter plot to ./plots/results/metrics_scatter_2d.png
# Saved interactive 3D scatter plot to ./plots/results/metrics_scatter_3d.html

# %%
stats = calculate_results_statistics(all_metrics, save_csv_path=None)
stats.head(500)
# Out:
#               Algorithm                                  Metric         Min  \
# 35              genetic                        Algebraic Degree    4.000000
# 33              genetic               Bit Independece Criterion    0.223529
# 31              genetic                 Differential Uniformity    8.000000
# 34              genetic  Fixed points and opposite fixed points    2.000000
# 30              genetic                           Non-Linearity  104.000000
# 32              genetic              Strict Avalanche Criterion    0.093750
# 53    greedy_iterations                        Algebraic Degree    4.000000
# 51    greedy_iterations               Bit Independece Criterion    0.250122
# 49    greedy_iterations                 Differential Uniformity   10.000000
# 52    greedy_iterations  Fixed points and opposite fixed points    2.000000
# 48    greedy_iterations                           Non-Linearity   96.000000
# 50    greedy_iterations              Strict Avalanche Criterion    0.109375
# 47         greedy_stuck                        Algebraic Degree    4.000000
# 45         greedy_stuck               Bit Independece Criterion    0.226524
# 43         greedy_stuck                 Differential Uniformity   10.000000
# 46         greedy_stuck  Fixed points and opposite fixed points    1.000000
# 42         greedy_stuck                           Non-Linearity   96.000000
# 44         greedy_stuck              Strict Avalanche Criterion    0.109375
# 23          greedy_time                        Algebraic Degree    4.000000
# 21          greedy_time               Bit Independece Criterion    0.250490
# 19          greedy_time                 Differential Uniformity   10.000000
# 22          greedy_time  Fixed points and opposite fixed points    0.000000
# 18          greedy_time                           Non-Linearity   98.000000
# 20          greedy_time              Strict Avalanche Criterion    0.093750
# 29    random_iterations                        Algebraic Degree    4.000000
# 27    random_iterations               Bit Independece Criterion    0.260606
# 25    random_iterations                 Differential Uniformity   10.000000
# 28    random_iterations  Fixed points and opposite fixed points    0.000000
# 24    random_iterations                           Non-Linearity   98.000000
# 26    random_iterations              Strict Avalanche Criterion    0.125000
# 11          random_time                        Algebraic Degree    4.000000
# 9           random_time               Bit Independece Criterion    0.229557
# 7           random_time                 Differential Uniformity   10.000000
# 10          random_time  Fixed points and opposite fixed points    3.000000
# 6           random_time                           Non-Linearity   98.000000
# 8           random_time              Strict Avalanche Criterion    0.078125
# 41  steepest_iterations                        Algebraic Degree    4.000000
# 39  steepest_iterations               Bit Independece Criterion    0.254902
# 37  steepest_iterations                 Differential Uniformity   10.000000
# 40  steepest_iterations  Fixed points and opposite fixed points    1.000000
# 36  steepest_iterations                           Non-Linearity   94.000000
# 38  steepest_iterations              Strict Avalanche Criterion    0.093750
# 17       steepest_stuck                        Algebraic Degree    4.000000
# 15       steepest_stuck               Bit Independece Criterion    0.251106
# 13       steepest_stuck                 Differential Uniformity   10.000000
# 16       steepest_stuck  Fixed points and opposite fixed points    1.000000
# 12       steepest_stuck                           Non-Linearity   96.000000
# 14       steepest_stuck              Strict Avalanche Criterion    0.093750
# 5         steepest_time                        Algebraic Degree    4.000000
# 3         steepest_time               Bit Independece Criterion    0.258178
# 1         steepest_time                 Differential Uniformity   10.000000
# 4         steepest_time  Fixed points and opposite fixed points    1.000000
# 0         steepest_time                           Non-Linearity   98.000000
# 2         steepest_time              Strict Avalanche Criterion    0.109375
#
#            Max        Mean      Median       Std
# 35    4.000000    4.000000    4.000000  0.000000
# 33    0.251106    0.237318    0.237318  0.019500
# 31   10.000000    9.000000    9.000000  1.414214
# 34    2.000000    2.000000    2.000000  0.000000
# 30  104.000000  104.000000  104.000000  0.000000
# 32    0.109375    0.101562    0.101562  0.011049
# 53    4.000000    4.000000    4.000000  0.000000
# 51    0.272864    0.259053    0.254173  0.012131
# 49   12.000000   11.333333   12.000000  1.154701
# 52    3.000000    2.333333    2.000000  0.577350
# 48   98.000000   96.666667   96.000000  1.154701
# 50    0.125000    0.119792    0.125000  0.009021
# 47    4.000000    4.000000    4.000000  0.000000
# 45    0.295381    0.251238    0.231810  0.038319
# 43   12.000000   11.333333   12.000000  1.154701
# 46    5.000000    2.333333    1.000000  2.309401
# 42   96.000000   96.000000   96.000000  0.000000
# 44    0.140625    0.130208    0.140625  0.018042
# 23    4.000000    4.000000    4.000000  0.000000
# 21    0.343750    0.293930    0.287551  0.046956
# 19   10.000000   10.000000   10.000000  0.000000
# 22    3.000000    1.333333    1.000000  1.527525
# 18   98.000000   98.000000   98.000000  0.000000
# 20    0.109375    0.098958    0.093750  0.009021
# 29    4.000000    4.000000    4.000000  0.000000
# 27    0.288944    0.278608    0.286275  0.015647
# 25   12.000000   10.666667   10.000000  1.154701
# 28    3.000000    1.666667    2.000000  1.527525
# 24   98.000000   98.000000   98.000000  0.000000
# 26    0.203125    0.156250    0.140625  0.041340
# 11    4.000000    4.000000    4.000000  0.000000
# 9     0.281387    0.252215    0.245701  0.026522
# 7    12.000000   10.666667   10.000000  1.154701
# 10    4.000000    3.666667    4.000000  0.577350
# 6    98.000000   98.000000   98.000000  0.000000
# 8     0.125000    0.093750    0.078125  0.027063
# 41    4.000000    4.000000    4.000000  0.000000
# 39    0.275040    0.261994    0.256038  0.011313
# 37   12.000000   10.666667   10.000000  1.154701
# 40    4.000000    2.333333    2.000000  1.527525
# 36   96.000000   94.666667   94.000000  1.154701
# 38    0.109375    0.104167    0.109375  0.009021
# 17    4.000000    4.000000    4.000000  0.000000
# 15    0.320394    0.276559    0.258178  0.038126
# 13   12.000000   11.333333   12.000000  1.154701
# 16    2.000000    1.666667    2.000000  0.577350
# 12   98.000000   97.333333   98.000000  1.154701
# 14    0.125000    0.109375    0.109375  0.015625
# 5     4.000000    4.000000    4.000000  0.000000
# 3     0.292611    0.276821    0.279673  0.017392
# 1    12.000000   11.333333   12.000000  1.154701
# 4     3.000000    2.000000    2.000000  1.000000
# 0    98.000000   98.000000   98.000000  0.000000
# 2     0.125000    0.114583    0.109375  0.009021
